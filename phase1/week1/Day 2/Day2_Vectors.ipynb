# %%
import numpy as np
import matplotlib.pyplot as plt

#define basis vectors
i_hat = np.array([1,0])
j_hat = np.array([0,1])

#express (3,4) as a linear combination
target = 3 * i_hat + 4 * j_hat
print(f"3*ihat + 4*jhat =  {target}")

# try different bases
new_i = np.array([2,1])
new_j = np.array([1,2])
# what linear combination of new_i and new_j gives (3,4)
print([4/3] [3,4])
# Out:
# 3*ihat + 4*jhat =  [3 4]
# <>:16: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:16: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# /tmp/ipykernel_32/2678393337.py:16: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
#   print([4/3] [3,4])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 16
#      14 new_j = np.array([1,2])
#      15 # what linear combination of new_i and new_j gives (3,4)
# ---> 16 print([4/3] [3,4])
#
# TypeError: list indices must be integers or slices, not tuple
